# %%
# !pip install diffusers transformers accelerate scipy safetensors
# Out:
# Collecting diffusers
#   Downloading diffusers-0.37.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: transformers in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (5.2.0)
# Collecting accelerate
#   Downloading accelerate-1.13.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: scipy in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (1.17.0)
# Requirement already satisfied: safetensors in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (0.7.0)
# Requirement already satisfied: importlib_metadata in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from diffusers) (8.7.1)
# Requirement already satisfied: filelock in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from diffusers) (3.20.3)
# Requirement already satisfied: httpx<1.0.0 in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from diffusers) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.34.0 in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from diffusers) (1.3.7)
# Requirement already satisfied: numpy in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from diffusers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from diffusers) (2026.1.15)
# Requirement already satisfied: requests in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from diffusers) (2.32.5)
# Requirement already satisfied: Pillow in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from diffusers) (12.0.0)
# Requirement already satisfied: anyio in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx<1.0.0->diffusers) (4.12.1)
# Requirement already satisfied: certifi in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx<1.0.0->diffusers) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx<1.0.0->diffusers) (1.0.9)
# Requirement already satisfied: idna in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx<1.0.0->diffusers) (2.10)
# Requirement already satisfied: h11>=0.16 in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpcore==1.*->httpx<1.0.0->diffusers) (0.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (2026.1.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (1.2.0)
# Requirement already satisfied: packaging>=20.9 in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (6.0.3)
# Requirement already satisfied: shellingham in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (1.5.4)
# Requirement already satisfied: tqdm>=4.42.1 in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (4.67.1)
# Requirement already satisfied: typer-slim in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (0.21.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (4.15.0)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: psutil in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from accelerate) (7.2.1)
# Requirement already satisfied: torch>=2.0.0 in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from accelerate) (2.10.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from torch>=2.0.0->accelerate) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: colorama in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from tqdm>=4.42.1->huggingface-hub<2.0,>=0.34.0->diffusers) (0.4.6)
# Requirement already satisfied: zipp>=3.20 in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from importlib_metadata->diffusers) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests->diffusers) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests->diffusers) (2.6.3)
# Requirement already satisfied: click>=8.0.0 in C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages (from typer-slim->huggingface-hub<2.0,>=0.34.0->diffusers) (8.1.8)
# Downloading diffusers-0.37.0-py3-none-any.whl (5.0 MB)
#    ---------------------------------------- 0.0/5.0 MB ? eta -:--:--
#    ------------ --------------------------- 1.6/5.0 MB 8.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 2.9/5.0 MB 7.0 MB/s eta 0:00:01
#    ------------------------------- -------- 3.9/5.0 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 5.0/5.0 MB 6.2 MB/s  0:00:00
# Downloading accelerate-1.13.0-py3-none-any.whl (383 kB)
# Installing collected packages: diffusers, accelerate
#
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    ---------------------------------------- 2/2 [accelerate]
#
# Successfully installed accelerate-1.13.0 diffusers-0.37.0
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages)

# %%
import torch
from diffusers import StableDiffusionPipeline, DPMSolverMultistepScheduler

model_id = "stabilityai/stable-diffusion-2-1"

# Use the DPMSolverMultistepScheduler (DPM-Solver++) scheduler here instead
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe.scheduler = DPMSolverMultistepScheduler.from_config(pipe.scheduler.config)
pipe = pipe.to("cuda")

prompt = "a photo of an astronaut riding a horse on mars"
image = pipe(prompt).images[0]

image.save("astronaut_rides_horse.png")
# Out:
# Couldn't connect to the Hub: 401 Client Error. (Request ID: Root=1-69b2806b-6739e0061c717835445a1d65;1b4d363a-2ce5-45fb-9f71-2689090b2fdd)
#
# Repository Not Found for url: https://huggingface.co/api/models/stabilityai/stable-diffusion-2-1.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated. For more details, see https://huggingface.co/docs/huggingface_hub/authentication
# Invalid username or password..
# Will try to load from local cache.
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File c:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\utils\_http.py:657, in hf_raise_for_status(response, endpoint_name)
#     656 try:
# --> 657     response.raise_for_status()
#     658 except httpx.HTTPStatusError as e:
#
# File c:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpx\_models.py:829, in Response.raise_for_status(self)
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '401 Unauthorized' for url 'https://huggingface.co/api/models/stabilityai/stable-diffusion-2-1'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/401
#
# The above exception was the direct cause of the following exception:
#
# RepositoryNotFoundError                   Traceback (most recent call last)
# File c:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages\diffusers\pipelines\pipeline_utils.py:1629, in DiffusionPipeline.download(cls, pretrained_model_name, **kwargs)
#    1628 try:
# -> 1629     info = model_info(pretrained_model_name, token=token, revision=revision)
#    1630 except (HfHubHTTPError, OfflineModeIsEnabled, requests.ConnectionError, httpx.NetworkError) as e:
#
# File c:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\utils\_validators.py:89, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      87 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 89 return fn(*args, **kwargs)
#
# File c:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\hf_api.py:2772, in HfApi.model_info(self, repo_id, revision, timeout, securityStatus, files_metadata, expand, token)
#    2771 r = get_session().get(path, headers=headers, timeout=timeout, params=params)
# -> 2772 hf_raise_for_status(r)
#    2773 data = r.json()
#
# File c:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\utils\_http.py:710, in hf_raise_for_status(response, endpoint_name)
#     701     message = (
#     702         f"{response.status_code} Client Error."
#     703         + "\n\n"
#    (...)    708         " https://huggingface.co/docs/huggingface_hub/authentication"
#     709     )
# --> 710     raise _format(RepositoryNotFoundError, message, response) from e
#     712 elif response.status_code == 400:
#
# RepositoryNotFoundError: 401 Client Error. (Request ID: Root=1-69b2806b-6739e0061c717835445a1d65;1b4d363a-2ce5-45fb-9f71-2689090b2fdd)
#
# Repository Not Found for url: https://huggingface.co/api/models/stabilityai/stable-diffusion-2-1.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated. For more details, see https://huggingface.co/docs/huggingface_hub/authentication
# Invalid username or password.
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 7
#       4 model_id = "stabilityai/stable-diffusion-2-1"
#       6 # Use the DPMSolverMultistepScheduler (DPM-Solver++) scheduler here instead
# ----> 7 pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
#       8 pipe.scheduler = DPMSolverMultistepScheduler.from_config(pipe.scheduler.config)
#       9 pipe = pipe.to("cuda")
#
# File c:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\utils\_validators.py:89, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      85         validate_repo_id(arg_value)
#      87 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 89 return fn(*args, **kwargs)
#
# File c:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages\diffusers\pipelines\pipeline_utils.py:853, in DiffusionPipeline.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     848     if pretrained_model_name_or_path.count("/") > 1:
#     849         raise ValueError(
#     850             f'The provided pretrained_model_name_or_path "{pretrained_model_name_or_path}"'
#     851             " is neither a valid local path nor a valid repo id. Please check the parameter."
#     852         )
# --> 853     cached_folder = cls.download(
#     854         pretrained_model_name_or_path,
#     855         cache_dir=cache_dir,
#     856         force_download=force_download,
#     857         proxies=proxies,
#     858         local_files_only=local_files_only,
#     859         token=token,
#     860         revision=revision,
#     861         from_flax=from_flax,
#     862         use_safetensors=use_safetensors,
#     863         use_onnx=use_onnx,
#     864         custom_pipeline=custom_pipeline,
#     865         custom_revision=custom_revision,
#     866         variant=variant,
#     867         dduf_file=dduf_file,
#     868         load_connected_pipeline=load_connected_pipeline,
#     869         **kwargs,
#     870     )
#     871 else:
#     872     cached_folder = pretrained_model_name_or_path
#
# File c:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\utils\_validators.py:89, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      85         validate_repo_id(arg_value)
#      87 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 89 return fn(*args, **kwargs)
#
# File c:\Users\mohur\AppData\Local\Programs\Python\Python311\Lib\site-packages\diffusers\pipelines\pipeline_utils.py:1823, in DiffusionPipeline.download(cls, pretrained_model_name, **kwargs)
#    1820     raise
#    1821 else:
#    1822     # 2. we forced `local_files_only=True` when `model_info` failed
# -> 1823     raise EnvironmentError(
#    1824         f"Cannot load model {pretrained_model_name}: model is not cached locally and an error occurred"
#    1825         " while trying to fetch metadata from the Hub. Please check out the root cause in the stacktrace"
#    1826         " above."
#    1827     ) from model_info_call_error
#
# OSError: Cannot load model stabilityai/stable-diffusion-2-1: model is not cached locally and an error occurred while trying to fetch metadata from the Hub. Please check out the root cause in the stacktrace above.

# %%
# make sure you're logged in with `huggingface-cli login`
from torch import autocast
from diffusers import StableDiffusionPipeline

pipe = StableDiffusionPipeline.from_pretrained(
	"CompVis/stable-diffusion-v1-4",
	use_auth_token=True
).to("cuda")

prompt = "horse image"
with autocast("cuda"):
    image = pipe(prompt)["images"][0]

image.save("horse.png")
# Out:
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 16 files:   0%|          | 0/16 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/492M [00:00<?, ?B/s]
# scheduler/scheduler_config.json:   0%|          | 0.00/313 [00:00<?, ?B/s]
# safety_checker/config.json:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# text_encoder/config.json:   0%|          | 0.00/592 [00:00<?, ?B/s]
# (…)kpoints/scheduler_config-checkpoint.json:   0%|          | 0.00/209 [00:00<?, ?B/s]
# tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# (…)ature_extractor/preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# unet/config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# tokenizer/special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# tokenizer/tokenizer_config.json:   0%|          | 0.00/806 [00:00<?, ?B/s]
# vae/config.json:   0%|          | 0.00/551 [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# Keyword arguments {'use_auth_token': True} are not expected by StableDiffusionPipeline and will be ignored.
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
